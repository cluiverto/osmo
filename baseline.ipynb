# %%
import torch
import torch_geometric
import rdkit
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from torch_geometric.data import Data, DataLoader
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def smiles_to_graph(smiles):
    """Konwertuje SMILES na graf molekularny dla PyTorch Geometric"""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    
    # Cechy atomów
    x = []
    for atom in mol.GetAtoms():
        atom_features = [
            atom.GetAtomicNum(),
            atom.GetDegree(),
            atom.GetFormalCharge(),
            atom.GetHybridization(),
            atom.GetIsAromatic(),
            atom.GetTotalNumHs()
        ]
        x.append(atom_features)
    
    x = torch.tensor(x, dtype=torch.float)
    
    # Krawędzie
    edge_indices = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        edge_indices.append([i, j])
        edge_indices.append([j, i])  # Graf nieskierowany
        
    if len(edge_indices) == 0:  # Molekuła bez wiązań
        edge_index = torch.zeros((2, 0), dtype=torch.long)
    else:
        edge_index = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    
    # Cechy krawędzi (wiązań)
    edge_attr = []
    for bond in mol.GetBonds():
        bond_type = bond.GetBondType()
        is_conjugated = bond.GetIsConjugated()
        is_in_ring = bond.IsInRing()
        bond_features = [
            bond_type == Chem.BondType.SINGLE, 
            bond_type == Chem.BondType.DOUBLE,
            bond_type == Chem.BondType.TRIPLE,
            bond_type == Chem.BondType.AROMATIC,
            is_conjugated,
            is_in_ring
        ]
        # Dodajemy cechę dla obu kierunków krawędzi
        edge_attr.append(bond_features)
        edge_attr.append(bond_features)
    
    if len(edge_attr) == 0:
        edge_attr = torch.zeros((0, 6), dtype=torch.float)
    else:
        edge_attr = torch.tensor(edge_attr, dtype=torch.float)
    
    data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)
    return data

# %%
smiles = "OCC(C)(O)c1onc(c2ncn3c2CN(C)C(c4c3cccc4Cl)=O)n1"  # Etanol
molecule = Chem.MolFromSmiles(smiles)
molecule

# %%
x = smiles_to_graph(smiles)
x
# Out:
# Data(x=[27, 6], edge_index=[2, 60], edge_attr=[60, 6])

# %%
import pyrfume

molecules = pyrfume.load_data(
    "goodscents/molecules.csv"
)  # Load the data we created in the last chapter
cids = molecules.IsomericSMILES.tolist()

# %%
for i in cids:
    s = []
    s.apply(smiles_to_graph(smiles))
    print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 3
#       1 for i in cids:
#       2     s = []
# ----> 3     s.apply(smiles_to_graph(smiles))
#       4     print(s)
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
cids
# Out:
# ['CC(CN)O',
#  'CC(C)C(=O)C(=O)O',
#  'C(CC(=O)O)C(=O)C(=O)O',
#  'CCC(=O)C(=O)O',
#  'CC(C)CC(=O)C(=O)O',
#  'C1=CC(=C(C=C1C(=O)O)O)O',
#  'C1=CC=C(C=C1)CCC(=O)O',
#  'C(CC(=O)O)CN',
#  'C1=CC(=CC=C1CO)O',
#  'C1=CC(=CC=C1C=O)O',
#  'C1=CC(=CC=C1C(=O)O)O',
#  'CC(=O)O',
#  'CC=O',
#  'CC(=O)N',
#  'CC(C(=O)C)O',
#  'CC(=O)C',
#  'C(CCC(=O)O)CC(=O)O',
#  'N',
#  'C1C(C(C(C(O1)O)O)O)O',
#  'C(CN)C(=O)O',
#  'C1=CC=C(C=C1)C=O',
#  'C1=CC=C(C=C1)C(=O)O',
#  'C1=CC=C(C=C1)CO',
#  'CCCC=O',
#  'CC(C(C)O)O',
#  'CCCCO',
#  'CCCC(=O)O',
#  'C(=O)=O',
#  'C(=O)O',
#  'C1=CC=C(C=C1)C=CC=O',
#  'C1=CC=C(C=C1)C=CCO',
#  'C(C(=CC(=O)O)C(=O)O)C(=O)O',
#  'C(C(=O)O)C(CC(=O)O)(C(=O)O)O',
#  'C1=CC=C2C(=C1)C=CC(=O)O2',
#  'CC(C)C1=CC=C(C=C1)CO',
#  'CC(C)C1=CC=C(C=C1)C=O',
#  'COC1=C(C=CC(=C1)C=C)O',
#  'CC1=CC=CC=C1O',
#  'C1=CC=C(C(=C1)C(=O)O)O',
#  'CC1=CC(=CC=C1)O',
#  'CCCCCCCC(=O)O',
#  'S',
#  'C(C(C(=O)O)N)C(=O)O',
#  'CCCCCCCC=O',
#  'COC1=CC=CC=C1O',
#  'C(C(C(=O)O)O)C(=O)O',
#  'CCC=O',
#  'CSCCC(=O)O',
#  'CC(C(=O)O)N',
#  'CC(C(=O)O)O',
#  'CC(=O)C(=O)C',
#  'C1CC(=O)OC2=CC=CC=C21',
#  'C(C(=O)CO)O',
#  'CS(=O)C',
#  'CCO',
#  'C(=CC(=O)O)C(=O)O',
#  'C(CC(=O)O)CC(=O)O',
#  'C(C(=O)O)N',
#  'C(C(CO)O)O',
#  'C(C(=O)O)O',
#  'CCC(C)C(C(=O)O)N',
#  'C1=CC=C2C(=C1)C=CN2',
#  'CC(C)CC(C(=O)O)N',
#  'C(CCN)CC(C(=O)O)N',
#  'C(C(C(=O)O)O)(C(=O)O)O',
#  'CSCCC(C(=O)O)N',
#  'CS',
#  'CC(=O)C=O',
#  'CO',
#  'C1=CC=C2C=CC=CC2=C1',
#  '[N-]=[N+]=O',
#  'CCCCCCCCO',
#  'O',
#  'C(C(=O)C(=O)O)O',
#  'C(=O)(C(=O)O)O',
#  'CCCCCCCCCCCCCCCC=O',
#  'CCCCCCCCCCCCCCCC(=O)O',
#  'C1=CC=C(C=C1)CC(C(=O)O)N',
#  'C1=CC=C(C=C1)O',
#  'C1=CC=C(C=C1)CC(=O)C(=O)O',
#  'C1=CC=C(C=C1)CC=O',
#  'C1=CC=C(C=C1)CC(=O)O',
#  'C1=CC=C(C=C1)CCN',
#  'OP(=O)(O)O',
#  'CC(CO)O',
#  'CCCO',
#  'CCC(=O)O',
#  'C(CCN)CN',
#  'C1=CC=NC=C1',
#  'CC(=O)C(=O)O',
#  'CSC',
#  'CNCC(=O)O',
#  'C(CC(=O)O)C(=O)O',
#  'C(CS(=O)(=O)O)N',
#  'C1CCSC1',
#  'CC1=C(SC=N1)CCO',
#  'CC1=CC=CC=C1',
#  'C[N+](C)(C)[O-]',
#  'CN(C)C',
#  'CC(C)C(C(=O)O)N',
#  'COC1=C(C=CC(=C1)C=O)O',
#  'CC1CCCC2(C1(CCCC2)O)C',
#  'CC1CCC(C(C1)O)C(C)C',
#  'C1=CC(=C(C=C1O)O)C(=O)O',
#  'CC(=O)C1=CC(=C(C=C1)O)OC',
#  'C1=CC=C(C=C1)COC(=O)C2=CC=CC=C2',
#  'C1=CC=C(C=C1)CN=C=S',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)C',
#  'CC1(C2CCC1(C(=O)C2)C)C',
#  'CCCCCCCCCCCCCCCCO',
#  'CC1(C2CCC(O1)(CC2)C)C',
#  'CC1=CC=C(C=C1)O',
#  'CCCCCCCCCC(=O)O',
#  'CCCCCCCCC(=O)NCC1=CC(=C(C=C1)O)OC',
#  'CCCCOC(=O)C1=CC=CC=C1C(=O)OCCCC',
#  'C1=CC=C(C=C1)C(=O)C2=CC=CC=C2',
#  'CCOCC',
#  'COC1=C(C=CC(=C1)CC=C)O',
#  'CC(=CCCC(=CCCC(=CCO)C)C)C',
#  'C(CC=O)CC=O',
#  'CC(C)C1=CC(=O)C(=CC=C1)O',
#  'CC(C)O',
#  'CCCCCCCCCCCC(=O)O',
#  'COC(=O)C1=CC=CC=C1O',
#  'COC1=CC(=CC2=C1OCO2)CC=C',
#  'C1=CC(=CC=C1CCC(=O)C2=C(C=C(C=C2O)O)O)O',
#  'C1CNCCN1',
#  '[Cl-].[K+]',
#  'CC(C)C1=C(C(=CC=C1)C(C)C)O',
#  'CCCOC(=O)C1=CC(=C(C(=C1)O)O)O',
#  'C1=CC(=CC(=C1)O)O',
#  'C1=CC=C2C(=C1)C(=O)NS2(=O)=O',
#  'C=CCC1=CC2=C(C=C1)OCO2',
#  'CCCCCCCCCCCCCCCCCC(=O)O',
#  'CC(=O)OCC(COC(=O)C)OC(=O)C',
#  'CC(C)(C)CC(C)(C)C1=CC=C(C=C1)OCCO',
#  'C1=CC(=CC=C1CCN)O',
#  'C=CCCCCCCCCC(=O)O',
#  'C([C@H]([C@H]([C@@H]([C@H](CO)O)O)O)O)O',
#  'C([C@@H](C(=O)O)N)S',
#  'C([C@@H](C(=O)O)N)C(=O)O',
#  'C(CC(=O)N)[C@@H](C(=O)O)N',
#  'C(CCN)C[C@@H](C(=O)O)N',
#  'C=CCN=C=S',
#  'C([C@H]([C@H]([C@@H](C(=O)CO)O)O)O)O',
#  'NS(=O)(=O)O',
#  'C[C@H](CCCC(C)C)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2CC=C4[C@@]3(CC[C@@H](C4)O)C)C',
#  'C1[C@H]([C@@H]([C@H]([C@H](O1)O)O)O)O',
#  'C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O',
#  'CCCC(=O)OCC(COC(=O)CCC)OC(=O)CCC',
#  'C1=CC=C(C=C1)CCO',
#  'C1=CC(=CC=C1C[C@@H](C(=O)O)N)O',
#  'CC(C)C[C@@H](C(=O)O)N',
#  'C(CN(CC(=O)[O-])CC(=O)[O-])N(CC(=O)[O-])CC(=O)[O-].[Na+].[Na+].[Ca+2]',
#  'CC(=O)[O-].CC(=O)[O-].[Ca+2]',
#  'C1=CC=C(C=C1)C[C@@H](C(=O)O)N',
#  'CCCCCC=O',
#  'CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCO.Cl.[Cl-]',
#  'CS(=O)(=O)C',
#  'C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.[Na+].[Na+].[Na+]',
#  'C([C@H]([C@H]([C@@H]([C@@H](CO)O)O)O)O)O',
#  'C([C@@H](C(=O)O)N)C(=O)N',
#  'C1=C(NC=N1)C[C@@H](C(=O)O)N',
#  'CCCCCO',
#  'CC(C)[C@@H](C(=O)O)N',
#  'C[C@H]([C@@H](C(=O)O)N)O',
#  'CC[C@H](C)[C@@H](C(=O)O)N',
#  'C(C[C@@H](C(=O)O)N)CN=C(N)N',
#  'CCN',
#  'CCS',
#  'CC(C)N',
#  'CC(C)S',
#  'CC1CO1',
#  'CC(C)(C)O',
#  'CC(C)(C)S',
#  'CCC(C)(C)O',
#  'CC(C)(C(C)(C)O)O',
#  'CC(=O)OC1CC2CCC1(C2(C)C)C',
#  'C[C@@H]1CC[C@@H]2C13CCC(C(C3)C2(C)C)(C)OC(=O)C',
#  'CCC(C)(CC)O',
#  'CCOC(=O)C1C(O1)(C)C2=CC=CC=C2',
#  'CCOC(=O)CC(CC(=O)OCC)(C(=O)OCC)OC(=O)C',
#  'CCCCOC(=O)CC(CC(=O)OCCCC)(C(=O)OCCCC)OC(=O)C',
#  'CCOC(=O)CC(CC(=O)OCC)(C(=O)OCC)O',
#  'CCCCOC(=O)CC(CC(=O)OCCCC)(C(=O)OCCCC)O',
#  'CC(C)C(=O)OC(C)(CCC=C(C)C)C=C',
#  'CCOP(=O)(OCC)OCC',
#  'CC1=CC(=O)CC(C1)(C)C',
#  'CCC(C)(CCCC(C)C)O',
#  'CC(=CCCC(C)(C=C)O)C',
#  'CCC(C)C',
#  'CC(C)CN',
#  'CC(C)CO',
#  'CC(C)C=O',
#  'CC(=C)C=O',
#  'CCC(C)O',
#  'CCC(=O)C',
#  'CC(=O)C=C',
#  'CC(=O)OC',
#  'CC(C)C(=O)O',
#  'CC(CCC=C(C)C)[C@H]1CC[C@@]2([C@@]1(CCC3=C2CC[C@@H]4[C@@]3(CC[C@@H](C4(C)C)O)C)C)C',
#  'CC1(C2CCC(C2)C1=C)C',
#  'CC(C)(C1=CC=C(C=C1)O)C2=CC=C(C=C2)O',
#  'CC1CCC(CC1)C(C)(C)OC(=O)C',
#  'CC1CCC(C=C1)(C(C)C)OC(=O)C',
#  'CC(CC=O)C1=CC=C(C=C1)C(C)(C)C',
#  'CC1=CCC2CC1C2(C)C',
#  'CC(=C)C(=O)OC',
#  'CC1=C(C(=O)CC1)O',
#  'CC1=C(C(=C(C(=C1[N+](=O)[O-])C(C)(C)C)[N+](=O)[O-])C)C(=O)C',
#  'CC1=CNC2=CC=CC=C12',
#  'CC1=C(C=C(C(=C1[N+](=O)[O-])OC)C(C)(C)C)[N+](=O)[O-]',
#  'C1CCC(CC1)OC(=O)C2=CC=CC=C2C(=O)OC3CCCCC3',
#  'CCOC(=O)C1=CC=CC=C1C(=O)OCC',
#  'C1=NC2=C(N1[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O)(O)O)O)O)NC(=NC2=O)N',
#  'CCCCOC(=O)COC(=O)C1=CC=CC=C1C(=O)OCCCC',
#  'CNC1=CC=CC=C1C(=O)OC',
#  'COC1=CC=CC=C1C2=CC=CC=C2',
#  'CC(C)COC(=O)C1=CC=CC=C1O',
#  'CC(C)CCOC(=O)C1=CC=CC=C1O',
#  'CCOC(=O)C1=CC=CC=C1N',
#  'C1C2=CC=CC=C2C(=O)O1',
#  'C([C@H](C([C@H](CO)O)O)O)O',
#  'CCC(CC)C(=O)O',
#  'C1=COC(=C1)C(=O)O',
#  'CC(=O)C1=CC=CS1',
#  'CCC1=CC2=C(C=C1C(=O)C)C(CCC2(C)C)(C)C',
#  'CC1=CC(=C(C=C1)C(C)(C)C)O',
#  'CC(C)C1=CC=CC=C1O',
#  'CC1CCC(=C(C)C)CC2=C1CCC2C',
#  'CC1CCC(C(C1)OC(=O)C2=CC=CC=C2O)C(C)C',
#  'CC1=CC(=C(C=C1)C(=O)C)C',
#  'CC1CCC(C(=O)C1)C(C)C',
#  'CC1=CC(=O)C(CC1)C(C)C',
#  'CC1CCC(=C(C)C)C(=O)C1',
#  'CC1=CC(=C(C=C1)C(C)C)O',
#  'C1=CC=C(C(=C1)C=O)O',
#  'CC1=CC=CC2=CC=CC=C12',
#  'CC(=O)OC(C1=CC=CC=C1)C(Cl)(Cl)Cl',
#  'C1CCC(CC1)C2CCCCC2=O',
#  'C([C@@H]1[C@H]([C@@H]([C@H](C(=O)O1)O)O)O)O',
#  'C1=CC=C(C=C1)C(C2=CC=CC=C2)O',
#  'COC1=C(C(=CC=C1)OC)O',
#  'COC1=CC=CC=C1OC',
#  'C1=CC=C2C(=C1)C=CC=N2',
#  'CC1=CC2=CC=CC=C2C=C1',
#  'C1=CC=C2C=C(C=CC2=C1)S',
#  'CC1=CC2=C(C=C1)N=CC=C2',
#  'CC1=CC2=C(C=C1)OC(=O)C=C2',
#  'C1=CC=C(C=C1)C2=CC=CC=C2',
#  'COC1=CC2=CC=CC=C2C=C1',
#  'CC(=O)C1=CC2=CC=CC=C2C=C1',
#  'COC1=C(C=C(C=C1)CC=C)OC',
#  'CC=CC1=CC(=C(C=C1)OC)OC',
#  'CCOC1=CC2=CC=CC=C2C=C1',
#  'CC(C)CC1=NC2=CC=CC=C2C=C1',
#  'CC(=O)OC1=C(C=C(C=C1)CC=C)OC',
#  'CC=CC1=CC(=C(C=C1)OC(=O)C)OC',
#  'CC1=CC(=C(C=C1)O)OC',
#  'CC(C=O)C1=CC=CC=C1',
#  'CCC(C1=CC=CC=C1)O',
#  'CCC(=O)C1=CC=CC=C1',
#  'COC(=O)C1=CC=CC=C1',
#  'COC(=O)C1=CN=CC=C1',
#  'CCOC(=O)C1=CC=CC=C1',
#  'CC(=O)CC(=O)C1=CC=CC=C1',
#  'C1=CC=C(C=C1)C(=O)OC2=CC=CC=C2',
#  'CCOC(=O)CC(=O)C1=CC=CC=C1',
#  'CCCOC(=O)C1=CC=C(C=C1)O',
#  'CCCCOC(=O)C1=CC=C(C=C1)O',
#  'C1=CC=C(C=C1)C(=O)OOC(=O)C2=CC=CC=C2',
#  'CC(C)CCOC(=O)C1=CC=CC=C1',
#  'C1=CC=C(C=C1)CCOC(=O)C2=CC=CC=C2',
#  'CCCC1=CC2=C(C=C1)OCO2',
#  'CCCC(C(CC)CO)O',
#  'C1=CC=C2C(=C1)N=CS2',
#  'CC1=CC2=CC=CC=C2N1',
#  'CC1=NC2=CC=CC=C2O1',
#  'CC1=CC=CC=C1C',
#  'CC1=C(C=C(C=C1)O)C',
#  'CC1=CC(=C(C=C1)C)O',
#  'CC1C(O1)C2CCC3(C(C2)O3)C',
#  'CCC(C)CN',
#  'CCC(C)C=O',
#  'CCC(=O)CC',
#  'C1CC(=O)OC1',
#  'CN1C=CC=C1',
#  'CC1=CCC(CC1OC(=O)C)C(=C)C',
#  'CCOC(=O)C(C)C',
#  'CCOC(=O)C(=C)C',
#  'CCOC(=O)C(C)O',
#  'CCCCCCCCCCCC(=O)N(C)CC(=O)O',
#  'CC(C)COC(=O)C(C)C',
#  'CCCCOC(=O)C(C)C',
#  'CCC(CC)CO',
#  'CCC(CC)C=O',
#  'C1CC(OC1)CO',
#  'C1=COC(=C1)CO',
#  'C1=COC(=C1)C=O',
#  'C1=COC(=C1)CS',
#  'C1=CSC(=C1)C=O',
#  'CC(C)(C)C1=CC(=C(C=C1)O)O',
#  'CC(C)(C)C1CCC(CC1)O',
#  'CC(C)(C)C1CCC(=O)CC1',
#  'CC(C)(C)C1=CC=C(C=C1)O',
#  'C1CC(=O)N[C@@H]1C(=O)O',
#  'CC(C1=CC=CC=C1)O',
#  'CC(=O)C1=CC=CC=C1',
#  'C1CCC(CC1)C(=O)O',
#  'CC1=CCC(CC1O)C(=C)C',
#  'CC1=CCC(CC1=O)C(=C)C',
#  'CC1=CC=C(C=C1)C(=O)OC',
#  'COC(=O)C1=CC=C(C=C1)O',
#  'CC1CCC(CC1)C(C)C',
#  'CC1=CCC(C=C1)C(C)C',
#  'CC1=CCC(=CC1)C(C)C',
#  'CC1=CC=C(CC1)C(C)C',
#  'CC1=CC=C(C=C1)C(C)C',
#  'CC(C)C1=CC=C(C=C1)O',
#  'CC(=O)C1=CC=C(C=C1)Cl',
#  'CC(=O)C1=CC=C(C=C1)O',
#  'CC(=O)C1=CC=C(C=C1)OC',
#  'COC1=CC=C(C=C1)C(=O)O',
#  'C=CC1=CC=CC=C1',
#  'C1=CC=C(C=C1)CS',
#  'COC1=CC=CC=C1',
#  'CSC1=CC=CC=C1',
#  'CCC1=CC=CC=N1',
#  'CC1=CC(=CC=C1)OC',
#  'CC(C)(CC1=CC=CC=C1)O',
#  'CC(=CC1=CC=CC=C1)C=O',
#  'COC(=O)CC1=CC=CC=C1',
#  'C1COC(O1)CC2=CC=CC=C2',
#  'C1=CC=C(C=C1)CC2=CC=CC=C2',
#  'C1=CC=C(C=C1)OC2=CC=CC=C2',
#  'CCCCCCC(=CC1=CC=CC=C1)C=O',
#  'CCOC(=O)CC1=CC=CC=C1',
#  'C1=CC=C(C=C1)CC(=O)CC2=CC=CC=C2',
#  'COC1=CC=C(C=C1)COC(=O)CC2=CC=CC=C2',
#  'CC(C)CCOC(=O)CC1=CC=CC=C1',
#  'C1=CC=C(C=C1)CCOC(=O)CC2=CC=CC=C2',
#  'CCCN(CCC)CCC',
#  'CC(C)(CCC1=CC=CC=C1)O',
#  'CC(=O)OC(C)(C)CCC1=CC=CC=C1',
#  'CCCCC(CC)COC(=O)C',
#  'COC(=O)CCC1=CC=CC=C1',
#  'COC(=O)C=CC1=CC=CC=C1',
#  'CC(C)C(=O)OCC1=CC=CC=C1',
#  'CCOC(=O)C=CC1=CC=CC=C1',
#  'CCCC(=O)OCC1=CC=CC=C1',
#  'CC(C)CC(=O)OCC1=CC=CC=C1',
#  'CC(=O)OCCC1=CC=CC=C1',
#  'CC(C)C(=O)OCCC1=CC=CC=C1',
#  'C1=CC=C(C=C1)COCC2=CC=CC=C2',
#  'CCCC(=O)OCCC1=CC=CC=C1',
#  'CC(=O)OCC=CC1=CC=CC=C1',
#  'CCC(=O)OCC=CC1=CC=CC=C1',
#  'CC(C)C(=O)OCCCC1=CC=CC=C1',
#  'CCCC(=O)OCC=CC1=CC=CC=C1',
#  'C1=CC=C(C=C1)C=CBr',
#  'CC1=CC=C(C=C1)OC(=O)C(C)C',
#  'CC(=O)OCC1=CC=C(C=C1)OC',
#  'CCCC1=CC=C(C=C1)OC',
#  'CCCCC1CCC(=O)O1',
#  'C1=CC=C(C=C1)CCC=O',
#  'C1=CC=C(C=C1)COC=O',
#  'CCCCCC1CCC(=O)O1',
#  'C1=CC=C(C=C1)CCOC=O',
#  'C1=CC=C(C=C1)C=CCOC=O',
#  'CCCCCCCC1CCC(=O)O1',
#  'CCCCC(CC)CO',
#  'CC1=CC=C(C=C1)C=O',
#  'CCC1=CN=C(C=C1)C',
#  'CC1=CC=C(C=C1)OC',
#  'CC(C)COC(=O)CCC1=CC=CO1',
#  'COC1=CC=C(C=C1)CO',
#  'CCCC1CCC(=O)O1',
#  'CCC(=O)OCC',
#  'CCC(C)CC(=O)O',
#  'CC(=O)CC(=O)OC',
#  'CCC(C)OC(=O)C',
#  'CCOC(=O)CC(=O)OCC',
#  'CCCC(=O)OCC',
#  'CCOC(C)OCC',
#  'C1CCC(=O)NCC1',
#  'CCCC(=O)OCCC',
#  'CC1=CC(=C(C=C1)O)C',
#  'CCC(=O)OCCC(C)C',
#  'CCCCCC(=O)OCC(C)C',
#  'CC(CCC=C(C)C)CCOC=O',
#  'CCC(=O)OCCC(C)CCCC(=C)C',
#  'CCCCCCCCCCCCCCCCCC(=O)OCCOCCO',
#  'CCCOC(=O)CCCCC(=O)OCCC',
#  'CC(C)CCCC(C)CCO',
#  'C[C@@H](CCC=C(C)C)CCO',
#  'CC(CCC=C(C)C)CC=O',
#  'CCCC(=O)OCCC(C)C',
#  'CCCCCCC(=O)OCC',
#  'CCCC(=O)OC(=O)CCC',
#  'CCCCCCCC(=O)OCC',
#  'CCCCCCCCCCCC(=O)OCC',
#  'CCCCC(=O)CC',
#  'CCCOC(=O)CC',
#  'COC(=O)CCC(=O)OC',
#  'CCCCCC(=O)OC',
#  'CCCCCCC(=O)OC',
#  'C=CC=O',
#  'CCCS',
#  'CCCN',
#  'C=CCO',
#  'C#CCO',
#  'C(=O)C=O',
#  'COC=O',
#  'CC(CC(C)(C)O)O',
#  'CC(CCCC(C)(C)O)CC=O',
#  'CC(C)CCN',
#  'CCCC(=O)C',
#  'CC(CCO)O',
#  'CC(C)CC(=O)C',
#  'CC(C)CC(C)O',
#  'CC(C)OC(=O)C',
#  'CC(=C)OC(=O)C',
#  'CC(=O)OC(=O)C',
#  'CC1CCC(=O)O1',
#  'CC1COC(=O)O1',
#  'CC1=CC(=CC=C1)C',
#  'CC1=CC(=NC=C1)C',
#  'CC1=NC(=CC=C1)C',
#  'CC1=CN=CC(=N1)C',
#  'COC(=O)CC(=O)OC',
#  'CCOC(=O)CC(C)C',
#  'CC(C)CC(CC(C)C)O',
#  'CC(C)CC(=O)CC(C)C',
#  'CC(C)CC(C)OC(=O)C',
#  'C1CCC(CC1)O',
#  'C1CCC(=O)CC1',
#  'C1=CC=C(C=C1)S',
#  'CC1CCCCN1',
#  'CC1=CC=CC=N1',
#  'CC1=NC=CN=C1',
#  'CCCCOC(=O)CC(C)C',
#  'CCCCOC(=O)CCC',
#  'C1CCCCCCCC(=O)OCCCCCCC1',
#  'CCCCOC(=O)CCCCCCCCC(=O)OCCCC',
#  'CC(=O)CCC=C',
#  'CCCCC(=O)O',
#  'CCCOC(=O)C',
#  'CCCCN',
#  'CCCCS',
#  'C(CS)CS',
#  'COCOC',
#  'CCNCC',
#  'CCOC=O',
#  'CCON=O',
#  'C1=CNC=C1',
#  'C1=COC=C1',
#  'C1=CSC=C1',
#  'CC(C)COC(=O)C',
#  'CCCCCCCCCCCCCC(=O)OC(C)C',
#  'CCCCCCCCCCCCCC(=O)OCCCC',
#  'CCCCCCCCCC(=O)OCC',
#  'CCOC(=O)CCCCCCCCC(=O)OCC',
#  'CCCCCCCCCC(=O)OC',
#  'CCCCCC(=O)C',
#  'CC(C)CCOC=O',
#  'CCCCCN',
#  'CCCCC=O',
#  'CCCCCS',
#  'CCCOC=O',
#  'CCSSCC',
#  'C1CCNCC1',
#  'CC(CNCC(C)O)O',
#  'CC(COCC(C)O)O',
#  'CCCCCCCC(=O)OC',
#  'CCCCCC#CC(=O)OC',
#  'CCCCCCC(=O)C',
#  'CCCCCCC(=O)O',
#  'CCCCCCN',
#  'CCCCCCO',
#  'CC=CC=CCO',
#  'CCCCCCS',
#  'C(CNCCO)N',
#  'C(CO)NCCO',
#  'C=CCOCCO',
#  'C(COCCO)O',
#  'CCCSCCC',
#  'CC(=O)OCCOC(=O)C',
#  'CCCCCCCCCCCCCCCCCC(=O)OCC',
#  'CCCCCCC=C',
#  'CCCCCCCO',
#  'CCCCCCC=O',
#  'COCCOCCO',
#  'CCCCCCC=CC(=O)OC',
#  'CCCCCCC#CC(=O)OC',
#  'COC(=O)CCCCCCCCC=C',
#  'CCCCCCCCCCCC(=O)OC',
#  'CCCCCCCCC',
#  'CCCCCCCCS',
#  'CCOCCOCCO',
#  'CCCCCCCCCCCCCCCC[N+](C)(C)C.[Cl-]',
#  'CCCCCCCCC(=O)O',
#  'CCCCCCCOC(=O)C',
#  'CCCCCCCCCC(=O)C',
#  'CCCCCCCCOC(=O)C',
#  'CCCCCCCCCCOC(=O)C',
#  'CCCCCCCOC=O',
#  'CCCCCCCCCCO',
#  'CCCCCCCCCC=O',
#  'CCCCCCCCOC=O',
#  'CCCCCCCCCCC(=O)O',
#  'CCCCCCCCCCCCCCCC(=O)OC',
#  'C=CCCCCCCCCCO',
#  'CCCCCCCCCCC=O',
#  'C=CCCCCCCCCC=O',
#  'CCCCCCCCCCCCO',
#  'CCCCCCCCCCCC=O',
#  'CCCCCCCCCCCCS',
#  'CCCCCCCCCCCCCCCCCC(=O)OC',
#  'CCCCCCCCCCCCOC(=O)C',
#  'CCCCCCCCCCCCCO',
#  'CCCCCCCCCCCCCCO',
#  'CCCCCCCCCCCCCCCCCCO',
#  'CCCCCCCCCCCCCCCCCCCC',
#  'COC',
#  'CC(C)(C=C)O',
#  'CC(=CCCC(C)(C=C)OC(=O)C)C',
#  'CC1CC(CC(C1)(C)C)O',
#  'CC(=O)CO',
#  'CCC(C)C(=O)O',
#  'CC1CC(C=C(C2C1CC(=C(C)C)C2)C)OC(=O)C',
#  'C1=CC=C(C=C1)OC(=O)C2=CC=CC=C2O',
#  'CC1CC(CC(C1)(C)C)OC(=O)C2=CC=CC=C2O',
#  'C1=CC=C(C=C1)COC(=O)C2=CC=CC=C2O',
#  'CCOC(=O)C1=CC=CC=C1O',
#  'CC1=C(C(=O)C=CO1)O',
#  'CC(=O)C1=CC=CC=C1O',
#  'C1=CC=C(C=C1)C(C(=O)C2=CC=CC=C2)O',
#  'C1=CC=C2C=NC=CC2=C1',
#  'COC1=C(C=C(C=C1)C=O)OC',
#  'CCOC(=O)C1=CC=C(C=C1)O',
#  'C1OC2=C(O1)C=C(C=C2)C=O',
#  'CC=CC1=CC2=C(C=C1)OCO2',
#  'C1CCC(=O)C1',
#  'CCOC1=C(C=CC(=C1)C=O)O',
#  'COC1=C(C=CC(=C1)C(=O)O)O',
#  'CCN(CC)CC',
#  'COC1=CC=C(C=C1)C(=O)OC',
#  'CC1=CC=C(C=C1)C(=O)C',
#  'COC(=O)C1=CC=CC=C1C(=O)OC',
#  'C1=CC=C(C=C1)CCOC(=O)C2=CC=CC=C2N',
#  'CC1CCC(C(C1)OC(=O)C2=CC=CC=C2N)C(C)C',
#  'COC(=O)C1=CC=CC=C1N',
#  'COC1=CC(=CC(=C1O)OC)C=O',
#  'COC1=CC=CC=C1C=O',
#  'CCCCOC(=O)C1=CC=CC=C1',
#  'CCCCCCCC1CCCC1=O',
#  'CC1=CC=CC=C1S',
#  'CC(C)(CO)C(C(=O)NCCC(=O)[O-])O.CC(C)(CO)C(C(=O)NCCC(=O)[O-])O.[Ca+2]',
#  'CCC(C)CO',
#  'C(C(C(=O)[O-])O)C(=O)[O-].[Na+].[Na+]',
#  'CCCCOC(=O)C(C)O',
#  'CC(=C)C1CCC(CC1)(C)O',
#  'C(CN(CC(=O)O)CC(=O)[O-])N(CC(=O)O)CC(=O)[O-].[Na+].[Na+]',
#  'CCC(=O)OCC(COC(=O)CC)OC(=O)CC',
#  'CC(CCC=C(C)C)CCOC(=O)CC1=CC=CC=C1',
#  'C1=CC(=C(C=C1C=O)O)O',
#  'C1=CC=C(C=C1)C=CC(=O)O',
#  'CC(=O)OCC1=CC=CC=C1',
#  'CCCCCCCCCCCC(=O)OCC1=CC=CC=C1',
#  'CC(C)CC(=O)OCCC1=CC=CC=C1',
#  'CC1=CC=C(C=C1)OC(=O)C',
#  'COC1=CC=C(C=C1)CC=C',
#  'CCOC(=O)C=C',
#  'CC(C)COC(=O)CCCCC(=O)OCC(C)C',
#  'CC(CCCC(=C)C)CCOC(=O)C',
#  'CCC(=O)OCCC(C)CCC=C(C)C',
#  'CCCC(=O)OCCC(C)CCC=C(C)C',
#  'CC(CCC=C(C)C)CCO',
#  'CC(=CCCC(=CC=O)C)C',
#  'CCOC(=O)C',
#  'CC(=CC(=O)C)C',
#  'CC(CCCC(C)(C)O)CC(OC)OC',
#  'CCOC(=O)CC(=O)C',
#  'CCCCCCC(=O)OCC=C',
#  'CC(=CCCC(=CCCC(C)(C=C)O)C)C',
#  'CCCCCC(=O)O',
#  'C1CCOCC1',
#  'CCCCCCC',
#  'CC=CC=CC=O',
#  'C1CNCCN1.C(CCC(=O)O)CC(=O)O',
#  'CCCCCCCCCCCCCCCC(=O)OC(C)C',
#  'CCCCCCOC(=O)C',
#  'CCCCOCCCC',
#  'CCCCCCCCCO',
#  'CCCCCCCCCOC(=O)C',
#  'COC1=CC=CC(=C1)O',
#  'C1=CC=C(C=C1)CSSCC2=CC=CC=C2',
#  'COC1=CC=C(C=C1)O',
#  'COC1=CC=C(C=C1)OC',
#  'CC(CCC=C(C)C)CCOC(=O)C',
#  'C(CC(=O)[O-])C(=O)[O-].[Na+].[Na+]',
#  'CC(=O)OC(C)(C)CC1=CC=CC=C1',
#  'COC1=CC(=CC=C1)OC',
#  'CCC(C)CCC(C)(CC)O',
#  'C1CCCC1',
#  'C1=CSC=N1',
#  'C1=CN=CC=N1',
#  'C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.[Ca+2]',
#  'CCC=CCC=CCC=CCCCCCCCC(=O)OC',
#  'CC(=O)OCC1=CC2=C(C=C1)OCO2',
#  'CC(=O)C1=CN=CC=C1',
#  'CCSCC',
#  'CC(=CCCC(=O)C)C',
#  'CC1=C(C(CCC1)(C)C)C=O',
#  'COC1=C(C=CC(=C1)C=CC=O)O',
#  'CC(=CCCC(=CC(=O)O)C)C',
#  'CCCCCCC(=O)CCCCCC',
#  'C[C@]12CC[C@@H](C1(C)C)C[C@H]2O',
#  'C[C@]12CCC(C1(C)C)CC2=O',
#  'C[C@@H]1CC[C@@H]2C13CC=C(C(C3)C2(C)C)C',
#  'CC(C)C12CCC(O1)(CC2)C',
#  'C(=O)([O-])[O-].[Ca+2]',
#  'CC1=CCCC2(C1CC(CC2)C(=C)C)C',
#  'CC1CCC2CC1C2(C)C',
#  'C[C@]12CCCC(C3[C@@H]1CCC3C2=C)(C)C',
#  'CC1=CC2C(CCC(=C2CC1)C)C(C)C',
#  'CC1CCC(C2=C1C=CC(=C2)C)C(C)C',
#  'CC(=CCC1=C(C=CC2=C1OC(=O)C=C2)OC)C',
#  'COC1=C(C2=C(C=C1CC=C)OCO2)OC',
#  'COC1=CC(=CC(=C1OC)OC)CC=C',
#  'CC1=CC(C(CC1)C(C)C)O',
#  'CC1=CC=NC2=CC=CC=C12',
#  'CCCC(=O)C1=CC=CC=C1',
#  'C1OC2=C(O1)C=C(C=C2)CO',
#  'CC1=CC(=C(C=C1C)O)C',
#  'CC=C(C)C=O',
#  'C(=O)([O-])[O-].[Na+].[Na+]',
#  'C1C=CC(=O)O1',
#  'CC1CCC(CC1)C(C)(C)O',
#  'CC1CCC(CC1=O)C(C)C',
#  'CC1CCC(=CC1=O)C(C)C',
#  'CC1=C(C=C(C=C1)C(C)C)O',
#  'C1=CC(=CC=C1CCO)O',
#  'CCCCCCCCCCCCCCC1CCC(=O)O1',
#  'CC(CCC=C(C)C)CC(=O)O',
#  'CC(C)CCCC(C)CCCC(C)CCCC(=O)C',
#  'C1CCCCCCCC(=O)CCCCCC1',
#  'CC(C)CC(=O)O',
#  'CSCCCO',
#  'C1CSCSC1',
#  'C1CSCCS1',
#  'CC(C)CCCC(C)CCCC(C)CCCC(C)(C=C)O',
#  'CCCC=CC=O',
#  'CC(=O)S',
#  'CC(=CCCC1(C2CCC(C2)C1=C)C)C',
#  'CC(C)CS',
#  'CCC(C)S',
#  'CC(C)C1=CC2=CC[C@@H]3[C@@]([C@H]2CC1)(CCC[C@@]3(C)C(=O)O)C',
#  'CC1(C2CC=C(C1C2)CO)C',
#  'CC1=CC(=O)C(=C(O1)O)C(=O)C',
#  'CC1=CC[C@@H]2[C@@H](C1)[C@@H](CC=C2C)C(C)C',
#  'COC1=C2C(=C(C(=C1)CC=C)OC)OCO2',
#  'CC1=C(C(=CC=C1)O)C',
#  'CC1=CC(=C(C(=C1)C)O)C',
#  'CC1=CC=CC=C1C=O',
#  'COC1=CC(=CC(=C1O)OC)C=CC(=O)O',
#  'COC1=CC2=C(C=C1)C=CC(=O)O2',
#  'CC1=CC=CC=C1OC(=O)C',
#  'CC(OC)OC',
#  'CC1=CC=CO1',
#  'CC1=CC=C(C=C1)C(C)O',
#  'CC(=C)C1CCC(=CC1)CO',
#  'CCC1=CN=CC=C1',
#  'CCCCCCCC(=O)OCC(COC(=O)CCCCCCC)OC(=O)CCCCCCC',
#  'COCC1=CC=CC=C1',
#  'CCOCC1=CC=CC=C1',
#  'CCCCC(=O)OCC',
#  'CCOC(=O)CCC(=O)C',
#  'CCCC(=O)OCC(C)C',
#  'CCCCCC(=O)OCCCCC',
#  'CCCCCOC(=O)CCC',
#  'CCC(=O)OCC(C)C',
#  'C(CS)S',
#  'C[Si]1(O[Si](O[Si](O[Si](O[Si](O[Si](O1)(C)C)(C)C)(C)C)(C)C)(C)C)C',
#  'CC(C)CCS',
#  'CCCC(=O)N',
#  'CC(=CC(=O)O)C',
#  'CC1=CSC(=N1)C',
#  'CC1CCCCCCCCCCCCC(=O)C1',
#  'CC(C)COC=O',
#  'CCN=C=S',
#  'CC(C)(CCCC(=C)C=C)O',
#  'CCCCCC(C)O',
#  'CCC=CCCO',
#  'CCCCSCCCC',
#  'CCCCCCCCCCCCCC(=O)O',
#  'CC1C2CC2(CC1=O)C(C)C',
#  'C(=O)([O-])[O-].[Mg+2]',
#  'CC1C2CC(C2(C)C)CC1=O',
#  'CC(C)C(=O)OC',
#  'COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.OS(=O)(=O)O',
#  'CC(=O)C1=CC=CC=C1N',
#  'C1C(OC2=CC(=CC(=C2C1=O)O)O)C3=CC(=C(C=C3)O)O',
#  'CCC(=O)OC',
#  'CC1=CC=CS1',
#  'CC(C)C1CCC(=C)C=C1',
#  'CC(C)CC(=O)OC',
#  'CN=C=S',
#  'CSC#N',
#  'CC(=CCO)C',
#  'CCCOC(=O)CC(C)C',
#  'CCC=CCCC=CC=O',
#  'CC1=CCC(CC1)(C(C)C)O',
#  'CC(C)C(=O)C',
#  'CCC(=O)C(C)C',
#  'CC1=C(C(=CC=C1)C)O',
#  'CC1=CC=CC=C1C(=O)C',
#  'CC(=O)C(=O)C1=CC=CC=C1',
#  'C=CCOC(=O)C1=CC=CC=C1',
#  'CCCCOC(=O)C1=CC=CO1',
#  'CC1CCCCC1O',
#  'CC1CCCCC1=O',
#  'CCC(CC)O',
#  'C(=O)([O-])[O-].[K+].[K+]',
#  'CCCCCC(=O)C(=O)C',
#  'CC1=CCC(=C(C)C)CC1',
#  'CC(=C1CCC(CC1)(C)O)C',
#  'CC(C)C1=CCC(CC1)(C)O',
#  'C1=CC=C(C=C1)NC2=CC=CC=C2',
#  'CC1=CC=C(C=C1)CO',
#  'CCC(C)CCO',
#  'CCCC(=O)CC',
#  'CCCC(CCC)O',
#  'CC(C)CC(=O)OCC(C)C',
#  'CCCCCCCC(=O)OCCCC',
#  'CCCCC(CC)O',
#  'CC1CCC(CC1)C',
#  'CC1CCC(=O)CC1',
#  'CCCCCC(CC)O',
#  'CCCCOC(=O)CC',
#  'CCCC(C)(C)O',
#  'CC(C)CC=O',
#  'CC1=CCC(=O)O1',
#  'CC1CCCC(C1)O',
#  'CC1CCCC(=O)C1',
#  'COC1=CC=CC(=C1)C=O',
#  'CC1CCC=CC1',
#  'CC1CCCC=C1',
#  'CC1=CCCCC1',
#  'CCCCOC(=O)CC(=O)C',
#  'CC(=O)CCC(=O)O',
#  'CCCCC(=O)C',
#  'CC(=O)COC(=O)C',
#  'CCCCN=C=S',
#  'CCCCOC=O',
#  'C=CCSCC=C',
#  'CCCCCCCCCCCC(=O)C',
#  'CC(C)C(C)O',
#  'CCC(=O)C(=O)C',
#  'CC(C)(CO)N',
#  'CC(C)OC(=O)C1=CC=CC=C1O',
#  'COC(=O)C1=CC=CO1',
#  'CCOC(=O)C1=CC=CO1',
#  'CCCOC(=O)C1=CC=CO1',
#  'CSC1=NC2=CC=CC=C2S1',
#  'CCC(C=C)O',
#  'CCOC(=O)C1=CC(=C(C=C1)O)OC',
#  'CCOC(=O)C(=O)C',
#  'CC(C)C(=O)OC(C)C',
#  'CC(C)(C1=CC=CC=C1)O',
#  'CC1CCC(CC1O)C(=C)C',
#  'CC1=CC=C(O1)C=O',
#  'CCC1=CC(=CC=C1)O',
#  'CC1=CC(=CC=C1)C=O',
#  'C1=CC=C(C=C1)COCCO',
#  'CC(=O)OC1CCCCC1',
#  'CCOC1=CC=C(C=C1)O',
#  'CC(=O)OCC1=CC=CO1',
#  'C1=COC(=C1)C=CC=O',
#  'CCC=C(C)C=O',
#  'CCCC(CC)O',
#  'CCCC(=O)OC',
#  'CCOC(=O)C=CC',
#  'CC(COC(=O)C)OC(=O)C',
#  'CCCCC(=O)OC',
#  'CCC(C)COC(=O)C',
#  'CCCCCCC(CC)O',
#  'CCCCCOC(=O)CC',
#  'CCSC',
#  'CSSC',
#  'CC(CC=C)O',
#  'CC=CC(=O)C',
#  'CC(C)OC=O',
#  'CC(C)SC(C)C',
#  'CC1=CC=C(O1)C',
#  'CCCC(C)OC(=O)C',
#  'CCCCCC(=O)OCCC',
#  'CCCCCC(=O)OCCCC',
#  'CC(C)CCCO',
#  'CCCCC(C)O',
#  'CCC=CC(=O)O',
#  'C=CSC=C',
#  'CCCCCCCCCCC(=O)OCC',
#  'COC(=O)CCCCC(=O)OC',
#  'CCCCSC',
#  'CC(C)CCCC(=O)O',
#  'CCCCCOC(=O)C',
#  'CCCCCCCCCCCCCCCC(=O)OCC',
#  'CCCCCCCC(C)O',
#  'CCCSSCCC',
#  'C(CCCC#N)CCC#N',
#  'CCCCSSCCCC',
#  'CCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCC',
#  'CC(=O)OCC1CCCO1',
#  'COC1=CC=C(C=C1)C=C',
#  'CCC(=O)OC(C)C',
#  'CC1=CC=C(S1)C',
#  'CC1NC(SC(S1)C)C',
#  'CCCCCOC=O',
#  'CCCCCCCCCCCCC(=O)O',
#  'CCCCCCCCCCCCCCOC(=O)C',
#  'CCCCCCCCCCCCCCCCCC=O',
#  'CCCCCCCCCCCCCCCCCCCCCCC',
#  'CC1=CC=C(C=C1)C2=CC=CC=C2',
#  'CCCC1=CC=CC=C1O',
#  'CCCOC(=O)C(C)C',
#  'CC(C)C1=CC=C(C=C1)C(=O)C',
#  'CCCC1=CC=C(C=C1)O',
#  'C1=CC=C(C=C1)CCC#N',
#  'CC(C)CCC(=O)O',
#  'CCCCCCCCCCCCCCCCCC(=O)OCC(C)C',
#  'CC(C)CCOC(=O)CC(C)C',
#  'CC=C(C)C=CC=C(C)C',
#  'CC1=CC(=O)OC(=C1)C',
#  'CCOC(=O)CCCCCCCCC=C',
#  'CCCCCCCCC(=O)C',
#  'CC1=CSC=N1',
#  'CCC1CCC(=O)O1',
#  'CC1=CC(=C(C(=C1)O)C)C',
#  'CCCC1CCCC(=O)O1',
#  'CSSCC1=CC=CC=C1',
#  'CC(=O)CCC1=CC=CO1',
#  'CCCCCC1CCCC(=O)O1',
#  'CCCCCCC1CCC(=O)O1',
#  'CCCCCCCC1CCCC(=O)O1',
#  'CC(=C)CCO',
#  'CCC=CC=O',
#  'CCCCCCCCCCOC=C',
#  'C1CCC(=O)C(=O)C1',
#  'CSCC1=CC=CC=C1',
#  'C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.[Ca+2].[Ca+2].[Ca+2]',
#  'CC(C(=O)[O-])O.CC(C(=O)[O-])O.[Ca+2]',
#  'CCCCCCCC(=O)C',
#  'CC1CCCC(=O)O1',
#  'CC1(SC(SC(S1)(C)C)(C)C)C',
#  'C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.[K+].[K+].[K+]',
#  'C(C(C(=O)[O-])O)(C(=O)[O-])O.[Na+].[Na+]',
#  'CCC(C)C(=O)OC',
#  'C=CCS',
#  'C1=CC=C(C=C1)SSC2=CC=CC=C2',
#  'CCCCCCCC(=O)CC',
#  'CCCC=CCO',
#  'C1CC=CC(=O)C1',
#  'CCC1=CC=C(C=C1)C(=O)C',
#  'CC(C)OC(=O)C1=CC=CC=C1',
#  'CC(=O)C1=CC=CC2=CC=CC=C21',
#  'CCCCCCCCCCCCCCC(=O)O',
#  'C1CC(=O)SC1',
#  'C1=CNC(=C1)C=O',
#  'C(=O)(O)[O-].[NH4+]',
#  'CC(=O)C1=CC=CN1',
#  'CC1=CC(=C(C=C1)C(C)C)OC',
#  'CCCCCCCC(=O)OCCCCCC',
#  'CC(C)CC(=O)OC(C=C)C(C)CC=C(C)C',
#  'CC(=O)OC(C)(C)CCCC(=C)C=C',
#  'CCCC=CC(=O)C',
#  'CC(=O)C1=CC=CC=N1',
#  'CC(CO)C1=CC=CC=C1',
#  'CC1=C(N=C(C(=N1)C)C)C',
#  'CCCCOC1=CC=CC=C1',
#  'CC(=O)C1=CC(=C(C=C1)OC)OC',
#  'CC1(CC2C1CCC3(C(O3)CCC2=C)C)C',
#  'CCCCCCCCCCCCOC(=O)C1=CC(=C(C(=C1)O)O)O',
#  'C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.N.[Fe+3]',
#  'CCCCCC(C)C(=O)O',
#  'CC(=CCOC(=O)C)C',
#  'C(CCCS)CCS',
#  'C(CCCCS)CCCS',
#  'CC(=O)C1=CC=CO1',
#  'CC1=CC(=O)CCC1',
#  'CC1=CC=C(O1)C(=O)C',
#  'CC1=CC=C(C=C1)C(C)(C)O',
#  'C(CO)C(CCO)OP(=O)([O-])[O-].C(C(COP(=O)([O-])[O-])O)O.[Fe+2].[Fe+2]',
#  'O=[Ca]',
#  'O=[Mg]',
#  'O=[Zn]',
#  'O=[V](=O)O[V](=O)=O',
#  'O=[Cu]',
#  'CC(C)CCCCCCC=O',
#  'CCCCCCCCCCCCCCCCCC(=O)OCC(C)O',
#  'CC1(C2CCC(=C)C1C2)C',
#  'COC(=O)C1=COC=C1',
#  'CCCCCCCCCCCCCCCCCC(=O)OCC([C@@H]1[C@H]([C@@H](CO1)O)O)O',
#  '[O-][Si]([O-])([O-])[O-].[Ca+2].[Ca+2]',
#  'C[C@]12CC[C@](C[C@H]1C3=CC(=O)[C@@H]4[C@]5(CC[C@@H](C([C@@H]5CC[C@]4([C@@]3(CC2)C)C)(C)C)O[C@@H]6[C@@H]([C@H]([C@@H]([C@H](O6)C(=O)O)O)O)O[C@H]7[C@@H]([C@H]([C@@H]([C@H](O7)C(=O)O)O)O)O)C)(C)C(=O)O',
#  'CC1=C(C2=C(CC[C@@](O2)(C)CCC[C@H](C)CCC[C@H](C)CCCC(C)C)C(=C1O)C)C',
#  'C1=CN(C=C1)CC2=CC=CO2',
#  'CC1=CC(=C(C=C1)O)C(=O)C',
#  'CC(CC(=O)OC)O',
#  'COC1=CC=CC=C1C=CC=O',
#  'CC=CC=CCOC(=O)C',
#  'CCC(C)CCC(=O)O',
#  'CC=CC(C)O',
#  'C1CCC(CC1)S',
#  'CCC=CCO',
#  'CCCCC=CCC(=O)O',
#  'CCCCCC1OCC(O1)C',
#  'CSCSC',
#  'CCC(=O)C=C',
#  'CCCC(=O)C=C',
#  'CC1(C2CCC(C2)(C1O)C)C',
#  'CC(C)(C)OC',
#  'CCCCCCCS',
#  'CC(=O)C1=CC2=CC=CC=C2O1',
#  'CCCCCCCCCC(C)O',
#  'CCCCC=CC(=O)C',
#  'C1CCC(C1)S',
#  'CCCCCCC1OCC(O1)CO',
#  'CCC=CCCOC(=O)C',
#  'CCCCCCCCCCCOC(=O)C',
#  'CCCCCCCCC(=O)OC',
#  'CCCCCCCCCCC(=O)OC',
#  'CC(C)OC(=O)C=C(C)C',
#  'CC1=C(SC=N1)C=C',
#  'C=CCOC(=O)CC1=CC=CC=C1',
#  'CCCCCCCCCCCCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC.[Cl-]',
#  'C=CCOC(=O)C=CC1=CC=CC=C1',
#  'CC(=O)C=CC1=CC=CC=C1',
#  'CCOC(=O)CCC1=CC=CC=C1',
#  'CCCCCCCC(=O)OCCC(C)C',
#  'CCCCCOC(=O)C1=CC=CC=C1',
#  'CCCCCOC(=O)C1=CC=CC=C1O',
#  'C=CCSSSCC=C',
#  'CCCC(=O)OCC=C',
#  'CCCCOC(=O)C1=CC=CC=C1O',
#  'CCCCOC(=O)CCC(=O)C',
#  'C=CCCC=O',
#  'CC(=C)C1CCC(=CC1)C=O',
#  'CCCCCCCCCCCCCCCCOCCO',
#  'CC1=CCC(CC1)C(C)(C)OC=O',
#  'CC(C)COC1=CC2=CC=CC=C2C=C1',
#  'C=CCSSCC=C',
#  'CCCSSCC=C',
#  'CCCSSC',
#  'CCCCCC(=O)OCCC(C)C',
#  'C[C@@H]1CC[C@H]([C@@H](C1)O)C(C)C',
#  'CCCCCCCOC(=O)CC',
#  'CC1=C(C(=CC=C1)C(C)(C)C)O',
#  'CC(=O)CCCC1=CC=CC=C1',
#  'CC1=CC[C@@H](CC1=O)C(=C)C',
#  'C1=CC=C(C=C1)CCN=C=S',
#  'CCCCCC1=CC=CC=N1',
#  'CCCCCCCCC1CCC(=O)O1',
#  'CCCCCC(=O)OC(C)C',
#  'CCCCCCCCCC(=O)OC(C)C',
#  'CCCOC(=O)C1=CC=CC=C1',
#  'CC1=NCCS1',
#  'CCCCCCOC(=O)C(C)C',
#  'CCCCCC=CC=CC=O',
#  'CCCCCC=CC=O',
#  'CCCCC(C)(C)CO',
#  'CC1(C2CCC1(C(C2)(C)O)C)C',
#  'CC1=NC2=CC=CC=C2N=C1C',
#  'CCC1C=CC(=O)O1',
#  'CC1CCCC(C1=O)(C)C',
#  'CC1=CC(=C(C=C1)O)C(C)(C)C',
#  'CC(C)CCC(=O)OC',
#  'CCCCCCCCC=CCCCCCCCC=O',
#  'CC(CCC=C(C)C)C=C',
#  'CCCCCCCCCCCC#N',
#  'CC1=CCC(CC1)C(C)(C)O',
#  'CCCCCC(C=C)OC(=O)C',
#  'CCC(C)COC(=O)C(C)CC',
#  'CC1=CC2=C(C=C1)C=CC(=O)O2',
#  'CCCCCCC=CC=O',
#  'CCCCC=CC=O',
#  'CC(=O)C1=CC(=C(C(=C1)OC)O)OC',
#  'CCCC=CCOC(=O)C',
#  'CCC(=O)C=CC',
#  'CC(=O)CCC1=CC=CC=C1',
#  'C1CCC(CC1)SSC2CCCCC2',
#  'CCOC(=O)COC1=CC=CC=C1',
#  'CCCCCCOC(=O)CCC',
#  'CCC(C)OCC',
#  'C=CCOC(=O)CCC1CCCCC1',
#  'CC(=O)NC1=CC=CC=C1C(=O)OC',
#  ...]

# %%
def process_smiles_list(smiles_list):
    """Przetwarza listę SMILES na listę grafów molekularnych"""
    graphs = []
    
    for smiles in smiles_list:
        graph = smiles_to_graph(smiles)
        if graph is not None:
            graphs.append(graph)
    
    return graphs

# Przykład użycia:
graphs = process_smiles_list(cids)

print(f"Pomyślnie przetworzono {len(graphs)} z {len(smiles_list)} SMILES")
# Out:
# Pomyślnie przetworzono 4565 z 4 SMILES

# %%
graphs
# Out:
# [Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[1, 6], edge_index=[2, 0], edge_attr=[0, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[1, 6], edge_index=[2, 0], edge_attr=[0, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[1, 6], edge_index=[2, 0], edge_attr=[0, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[17, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[18, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[17, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[21, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[20, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[20, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[2, 6], edge_index=[2, 0], edge_attr=[0, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[18, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[28, 6], edge_index=[2, 62], edge_attr=[62, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[23, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[9, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[16, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[19, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[22, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[28, 6], edge_index=[2, 54], edge_attr=[54, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[25, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[31, 6], edge_index=[2, 68], edge_attr=[68, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[17, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[21, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[19, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[24, 6], edge_index=[2, 52], edge_attr=[52, 6]),
#  Data(x=[16, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[24, 6], edge_index=[2, 52], edge_attr=[52, 6]),
#  Data(x=[24, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[19, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[20, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[18, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[17, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[12, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[16, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[19, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[18, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[26, 6], edge_index=[2, 50], edge_attr=[50, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[18, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[22, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[18, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[22, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[21, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[3, 6], edge_index=[2, 4], edge_attr=[4, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[19, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[19, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[17, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[18, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[20, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[31, 6], edge_index=[2, 56], edge_attr=[56, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[11, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[22, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[18, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[20, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[21, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[18, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[5, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[27, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[5, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[15, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[18, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[20, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[16, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[22, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[16, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[16, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[33, 6], edge_index=[2, 64], edge_attr=[64, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[24, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[17, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[5, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[29, 6], edge_index=[2, 62], edge_attr=[62, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[21, 6], edge_index=[2, 46], edge_attr=[46, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[21, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[22, 6], edge_index=[2, 42], edge_attr=[42, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[18, 6], edge_index=[2, 34], edge_attr=[34, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[23, 6], edge_index=[2, 44], edge_attr=[44, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[24, 6], edge_index=[2, 46], edge_attr=[46, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[29, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[13, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[16, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[4, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[13, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[17, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[5, 6], edge_index=[2, 6], edge_attr=[6, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[16, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[17, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[16, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[24, 6], edge_index=[2, 48], edge_attr=[48, 6]),
#  Data(x=[15, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[24, 6], edge_index=[2, 40], edge_attr=[40, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[2, 6], edge_index=[2, 2], edge_attr=[2, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[24, 6], edge_index=[2, 46], edge_attr=[46, 6]),
#  Data(x=[10, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[9, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[30, 6], edge_index=[2, 60], edge_attr=[60, 6]),
#  Data(x=[7, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[58, 6], edge_index=[2, 128], edge_attr=[128, 6]),
#  Data(x=[31, 6], edge_index=[2, 64], edge_attr=[64, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[5, 6], edge_index=[2, 8], edge_attr=[8, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[11, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[36, 6], edge_index=[2, 68], edge_attr=[68, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[15, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[20, 6], edge_index=[2, 38], edge_attr=[38, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[15, 6], edge_index=[2, 32], edge_attr=[32, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[6, 6], edge_index=[2, 10], edge_attr=[10, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[15, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[6, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[11, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[8, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[10, 6], edge_index=[2, 20], edge_attr=[20, 6]),
#  Data(x=[12, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[9, 6], edge_index=[2, 16], edge_attr=[16, 6]),
#  Data(x=[19, 6], edge_index=[2, 36], edge_attr=[36, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[13, 6], edge_index=[2, 24], edge_attr=[24, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[12, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[8, 6], edge_index=[2, 14], edge_attr=[14, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[10, 6], edge_index=[2, 18], edge_attr=[18, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[11, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[14, 6], edge_index=[2, 30], edge_attr=[30, 6]),
#  Data(x=[13, 6], edge_index=[2, 26], edge_attr=[26, 6]),
#  Data(x=[12, 6], edge_index=[2, 22], edge_attr=[22, 6]),
#  Data(x=[7, 6], edge_index=[2, 12], edge_attr=[12, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  Data(x=[14, 6], edge_index=[2, 28], edge_attr=[28, 6]),
#  ...]

# %%
for i in cids:
    i = smiles_to_graph(smiles)

    return

# %%
[x for x in cids]

# %%
return  ci
